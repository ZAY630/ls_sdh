# %%
import process_data as process
import pandas as pd

# %%
moer_df = pd.read_csv("moer_15.csv")
moer_df.head()
# Out:
#                     datetime       value        moer
# 0  2023-01-01 00:00:00+00:00  997.000000  452.638000
# 1  2023-01-01 00:15:00+00:00  995.000000  451.730000
# 2  2023-01-01 00:30:00+00:00  995.333333  451.881333
# 3  2023-01-01 00:45:00+00:00  995.333333  451.881333
# 4  2023-01-01 01:00:00+00:00  987.000000  448.098000

# %%
moer_df['datetime'] = pd.to_datetime(moer_df['datetime'])
moer_df['datetime'] = moer_df['datetime'].dt.tz_convert('America/Los_Angeles')

# %%
process.make_plot(moer_df, ['moer'], date='2023-11-14')
# Out:
# /Users/aoyuzou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
process.plot_hourly_heatmap(moer_df, ['moer'])

# %%
data_df = pd.read_csv("SW.csv")
data_df.head()
# Out:
#               datetime  SDH.SW.MSA.ATS-ES.PEAK DEMAND  \
# 0  2023-01-20 15:45:00                        78999.0
# 1  2023-01-20 16:00:00                        78999.0
# 2  2023-01-20 16:15:00                        78999.0
# 3  2023-01-20 16:30:00                        78999.0
# 4  2023-01-20 16:45:00                        78999.0
#
#    SDH.SW.MSA.MS41B.PEAK DEMAND  SDH.SW.MSA.CD4RA.PWR REAL 3 P  \
# 0                           0.0                        24999.0
# 1                           0.0                        26999.0
# 2                           0.0                        24999.0
# 3                           0.0                        23999.0
# 4                           0.0                        23999.0
#
#    SDH.SW.MSA.ATS-ES.PWR REAL 3 P  SDH.SW.MSB.MS41A.PEAK DEMAND  \
# 0                         16999.0                           0.0
# 1                         17999.0                           0.0
# 2                         17499.0                           0.0
# 3                         16999.0                           0.0
# 4                         17999.0                           0.0
#
#    SDH.SW.MSB.ATS-EL.PEAK DEMAND  SDH.SW.MSA.MSB.TIE.PWR REAL 3P  \
# 0                       109999.0                             0.0
# 1                       109999.0                             0.0
# 2                       109999.0                             0.0
# 3                       109999.0                             0.0
# 4                       109999.0                             0.0
#
#    SDH.SW.MSB.MAIN.PEAK DEMAND  SDH.SW.MSA.CD4RA.PEAK DEMAND  ...  \
# 0                     408999.0                      100999.0  ...
# 1                     408999.0                      100999.0  ...
# 2                     408999.0                      100999.0  ...
# 3                     408999.0                      100999.0  ...
# 4                     408999.0                      100999.0  ...
#
#    SDH.SW.MSA.CH-2.PWR REAL 3 P  SDH.SW.MSB.ATS-E02.REAL 3 PH  \
# 0                       71999.0                       30999.0
# 1                       73999.0                       30999.0
# 2                       70999.0                       27999.0
# 3                       73999.0                       24999.0
# 4                       68999.0                       30999.0
#
#    SDH.SW.MSA.MDC.PEAK DEMAND  SDH.SW.MSA.ATS-E1.PEAK DEMAND  \
# 0                     39999.0                       178999.0
# 1                     39999.0                       178999.0
# 2                     39999.0                       178999.0
# 3                     39999.0                       178999.0
# 4                     39999.0                       178999.0
#
#    SDH.SW.MSA.MS41B.PWR REAL 3 P  SDH.SW.MSA.MS41A.PEAK DEMAND  \
# 0                            0.0                      407999.0
# 1                            0.0                      407999.0
# 2                            0.0                      407999.0
# 3                            0.0                      407999.0
# 4                            0.0                      407999.0
#
#    SDH.SW.MSB.ATS-E02.PEAK DEMAND  SDH.SW.MSA.CD41A.PWR REAL 3 P  \
# 0                         33999.0                        29999.0
# 1                         33999.0                        32999.0
# 2                         33999.0                        25999.0
# 3                         33999.0                        27999.0
# 4                         33999.0                        29999.0
#
#    SDH.SW.MSB.MS41A.PWR REAL 3 P  SDH.SW.MSB.MAIN.PWR REAL 3 P
# 0                            0.0                      379999.0
# 1                            0.0                      367999.0
# 2                            0.0                      363499.0
# 3                            0.0                      368999.0
# 4                            0.0                      366499.0
#
# [5 rows x 37 columns]

# %%
data_df['datetime'] = pd.to_datetime(data_df['datetime'])
data_df
# Out:
#                  datetime  SDH.SW.MSA.ATS-ES.PEAK DEMAND  \
# 0     2023-01-20 15:45:00                        78999.0
# 1     2023-01-20 16:00:00                        78999.0
# 2     2023-01-20 16:15:00                        78999.0
# 3     2023-01-20 16:30:00                        78999.0
# 4     2023-01-20 16:45:00                        78999.0
# ...                   ...                            ...
# 33148 2023-12-31 22:45:00                        78999.0
# 33149 2023-12-31 23:00:00                        78999.0
# 33150 2023-12-31 23:15:00                        78999.0
# 33151 2023-12-31 23:30:00                        78999.0
# 33152 2023-12-31 23:45:00                        78999.0
#
#        SDH.SW.MSA.MS41B.PEAK DEMAND  SDH.SW.MSA.CD4RA.PWR REAL 3 P  \
# 0                               0.0                   24999.000000
# 1                               0.0                   26999.000000
# 2                               0.0                   24999.000000
# 3                               0.0                   23999.000000
# 4                               0.0                   23999.000000
# ...                             ...                            ...
# 33148                           0.0                   24999.000000
# 33149                           0.0                   23332.333333
# 33150                           0.0                   23999.000000
# 33151                           0.0                   24332.333333
# 33152                           0.0                   24499.000000
#
#        SDH.SW.MSA.ATS-ES.PWR REAL 3 P  SDH.SW.MSB.MS41A.PEAK DEMAND  \
# 0                             16999.0                           0.0
# 1                             17999.0                           0.0
# 2                             17499.0                           0.0
# 3                             16999.0                           0.0
# 4                             17999.0                           0.0
# ...                               ...                           ...
# 33148                         15999.0                           0.0
# 33149                         14999.0                           0.0
# 33150                         14999.0                           0.0
# 33151                         14999.0                           0.0
# 33152                         14999.0                           0.0
#
#        SDH.SW.MSB.ATS-EL.PEAK DEMAND  SDH.SW.MSA.MSB.TIE.PWR REAL 3P  \
# 0                           109999.0                             0.0
# 1                           109999.0                             0.0
# 2                           109999.0                             0.0
# 3                           109999.0                             0.0
# 4                           109999.0                             0.0
# ...                              ...                             ...
# 33148                       109999.0                             0.0
# 33149                       109999.0                             0.0
# 33150                       109999.0                             0.0
# 33151                       109999.0                             0.0
# 33152                       109999.0                             0.0
#
#        SDH.SW.MSB.MAIN.PEAK DEMAND  SDH.SW.MSA.CD4RA.PEAK DEMAND  ...  \
# 0                         408999.0                      100999.0  ...
# 1                         408999.0                      100999.0  ...
# 2                         408999.0                      100999.0  ...
# 3                         408999.0                      100999.0  ...
# 4                         408999.0                      100999.0  ...
# ...                            ...                           ...  ...
# 33148                     414999.0                      100999.0  ...
# 33149                     414999.0                      100999.0  ...
# 33150                     414999.0                      100999.0  ...
# 33151                     414999.0                      100999.0  ...
# 33152                     414999.0                      100999.0  ...
#
#        SDH.SW.MSA.CH-2.PWR REAL 3 P  SDH.SW.MSB.ATS-E02.REAL 3 PH  \
# 0                      71999.000000                  30999.000000
# 1                      73999.000000                  30999.000000
# 2                      70999.000000                  27999.000000
# 3                      73999.000000                  24999.000000
# 4                      68999.000000                  30999.000000
# ...                             ...                           ...
# 33148                      0.000000                  27999.000000
# 33149                    999.333333                  29665.666667
# 33150                      0.000000                  28999.000000
# 33151                    666.000000                  29999.000000
# 33152                    499.500000                  28999.000000
#
#        SDH.SW.MSA.MDC.PEAK DEMAND  SDH.SW.MSA.ATS-E1.PEAK DEMAND  \
# 0                         39999.0                       178999.0
# 1                         39999.0                       178999.0
# 2                         39999.0                       178999.0
# 3                         39999.0                       178999.0
# 4                         39999.0                       178999.0
# ...                           ...                            ...
# 33148                     39999.0                       178999.0
# 33149                     39999.0                       178999.0
# 33150                     39999.0                       178999.0
# 33151                     39999.0                       178999.0
# 33152                     39999.0                       178999.0
#
#        SDH.SW.MSA.MS41B.PWR REAL 3 P  SDH.SW.MSA.MS41A.PEAK DEMAND  \
# 0                                0.0                      407999.0
# 1                                0.0                      407999.0
# 2                                0.0                      407999.0
# 3                                0.0                      407999.0
# 4                                0.0                      407999.0
# ...                              ...                           ...
# 33148                            0.0                      407999.0
# 33149                            0.0                      407999.0
# 33150                            0.0                      407999.0
# 33151                            0.0                      407999.0
# 33152                            0.0                      407999.0
#
#        SDH.SW.MSB.ATS-E02.PEAK DEMAND  SDH.SW.MSA.CD41A.PWR REAL 3 P  \
# 0                             33999.0                   29999.000000
# 1                             33999.0                   32999.000000
# 2                             33999.0                   25999.000000
# 3                             33999.0                   27999.000000
# 4                             33999.0                   29999.000000
# ...                               ...                            ...
# 33148                         33999.0                   21999.000000
# 33149                         33999.0                   21332.333333
# 33150                         33999.0                   18499.000000
# 33151                         33999.0                   22665.666667
# 33152                         33999.0                   27499.000000
#
#        SDH.SW.MSB.MS41A.PWR REAL 3 P  SDH.SW.MSB.MAIN.PWR REAL 3 P
# 0                                0.0                 379999.000000
# 1                                0.0                 367999.000000
# 2                                0.0                 363499.000000
# 3                                0.0                 368999.000000
# 4                                0.0                 366499.000000
# ...                              ...                           ...
# 33148                            0.0                 338999.000000
# 33149                            0.0                 326332.333333
# 33150                            0.0                 338499.000000
# 33151                            0.0                 332999.000000
# 33152                            0.0                 317499.000000
#
# [33153 rows x 37 columns]

# %%
data_df['datetime'] = pd.to_datetime(data_df['datetime'])
data_df['datetime'] = data_df['datetime'].dt.tz_localize('America/Los_Angeles', nonexistent='shift_forward', ambiguous=True)

# %%
power_df = process.get_power(df=data_df, unit="W")
power_df.head()
# Out:
# /Users/aoyuzou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1851: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, val, pi)
#                    datetime  SDH.SW.MSA.CD4RA.PWR REAL 3 P  \
# 0 2023-01-20 15:45:00-08:00                         24.999
# 1 2023-01-20 16:00:00-08:00                         26.999
# 2 2023-01-20 16:15:00-08:00                         24.999
# 3 2023-01-20 16:30:00-08:00                         23.999
# 4 2023-01-20 16:45:00-08:00                         23.999
#
#    SDH.SW.MSA.ATS-ES.PWR REAL 3 P  SDH.SW.MSA.MSB.TIE.PWR REAL 3P  \
# 0                          16.999                             0.0
# 1                          17.999                             0.0
# 2                          17.499                             0.0
# 3                          16.999                             0.0
# 4                          17.999                             0.0
#
#    SDH.SW.MSA.MS41A.PWR REAL 3 P  SDH.SW.MSA.MDC.PWR REAL 3 P  \
# 0                        331.999                       22.999
# 1                        330.999                       23.999
# 2                        334.499                       24.499
# 3                        319.999                       23.999
# 4                        325.999                       23.499
#
#    SDH.SW.MSA.ATS-E2.PWR REAL 3 P  SDH.SW.MSB.MS41B.PWR REAL 3 P  \
# 0                          30.999                        179.999
# 1                          30.999                        177.999
# 2                          27.999                        175.499
# 3                          24.999                        186.999
# 4                          30.999                        160.999
#
#    SDH.SW.MSA.MAIN.PWR REAL 3 P  SDH.SW.MSA.MSB.PWR REAL 3 P  \
# 0                       537.999                          0.0
# 1                       539.999                          0.0
# 2                       546.999                          0.0
# 3                       535.999                          0.0
# 4                       542.499                          0.0
#
#    SDH.SW.MSB.ATS-EL.PWR REAL 3 P  SDH.SW.MSA.ATS-E1.PWR REAL 3 P  \
# 0                          93.999                          59.999
# 1                          95.999                          58.999
# 2                         102.999                          69.999
# 3                          94.999                          59.999
# 4                          99.999                          60.999
#
#    SDH.SW.MSB.CB4A.PWR REAL 3 P  SDH.SW.MSA.CH-2.PWR REAL 3 P  \
# 0                        55.999                        71.999
# 1                        55.999                        73.999
# 2                        57.999                        70.999
# 3                        55.999                        73.999
# 4                        54.999                        68.999
#
#    SDH.SW.MSA.MS41B.PWR REAL 3 P  SDH.SW.MSA.CD41A.PWR REAL 3 P  \
# 0                            0.0                         29.999
# 1                            0.0                         32.999
# 2                            0.0                         25.999
# 3                            0.0                         27.999
# 4                            0.0                         29.999
#
#    SDH.SW.MSB.MS41A.PWR REAL 3 P  SDH.SW.MSB.MAIN.PWR REAL 3 P
# 0                            0.0                       379.999
# 1                            0.0                       367.999
# 2                            0.0                       363.499
# 3                            0.0                       368.999
# 4                            0.0                       366.499

# %%
columns = ['SDH.SW.MSA.MAIN.PWR REAL 3 P']

# %%
process.make_plot(power_df, columns)
# Out:
# /Users/aoyuzou/Documents/Mac/ClassMaterial/ARCH299/SDH/process_data.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime'] = pd.to_datetime(df.iloc[:, 0])

# %%
process.plot_hourly_heatmap(power_df, columns)
# Out:
# /Users/aoyuzou/Documents/Mac/ClassMaterial/ARCH299/SDH/process_data.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df_temp = pd.merge(power_df, moer_df, on = 'datetime', how = 'outer')
df_temp = df_temp.reset_index()
df_temp.head()
# Out:
#                    datetime  SDH.SW.MSA.CD4RA.PWR REAL 3 P  \
# 0 2023-01-20 15:45:00-08:00                         24.999
# 1 2023-01-20 16:00:00-08:00                         26.999
# 2 2023-01-20 16:15:00-08:00                         24.999
# 3 2023-01-20 16:30:00-08:00                         23.999
# 4 2023-01-20 16:45:00-08:00                         23.999
#
#    SDH.SW.MSA.ATS-ES.PWR REAL 3 P  SDH.SW.MSA.MSB.TIE.PWR REAL 3P  \
# 0                          16.999                             0.0
# 1                          17.999                             0.0
# 2                          17.499                             0.0
# 3                          16.999                             0.0
# 4                          17.999                             0.0
#
#    SDH.SW.MSA.MS41A.PWR REAL 3 P  SDH.SW.MSA.MDC.PWR REAL 3 P  \
# 0                        331.999                       22.999
# 1                        330.999                       23.999
# 2                        334.499                       24.499
# 3                        319.999                       23.999
# 4                        325.999                       23.499
#
#    SDH.SW.MSA.ATS-E2.PWR REAL 3 P  SDH.SW.MSB.MS41B.PWR REAL 3 P  \
# 0                          30.999                        179.999
# 1                          30.999                        177.999
# 2                          27.999                        175.499
# 3                          24.999                        186.999
# 4                          30.999                        160.999
#
#    SDH.SW.MSA.MAIN.PWR REAL 3 P  SDH.SW.MSA.MSB.PWR REAL 3 P  \
# 0                       537.999                          0.0
# 1                       539.999                          0.0
# 2                       546.999                          0.0
# 3                       535.999                          0.0
# 4                       542.499                          0.0
#
#    SDH.SW.MSB.ATS-EL.PWR REAL 3 P  SDH.SW.MSA.ATS-E1.PWR REAL 3 P  \
# 0                          93.999                          59.999
# 1                          95.999                          58.999
# 2                         102.999                          69.999
# 3                          94.999                          59.999
# 4                          99.999                          60.999
#
#    SDH.SW.MSB.CB4A.PWR REAL 3 P  SDH.SW.MSA.CH-2.PWR REAL 3 P  \
# 0                        55.999                        71.999
# 1                        55.999                        73.999
# 2                        57.999                        70.999
# 3                        55.999                        73.999
# 4                        54.999                        68.999
#
#    SDH.SW.MSA.MS41B.PWR REAL 3 P  SDH.SW.MSA.CD41A.PWR REAL 3 P  \
# 0                            0.0                         29.999
# 1                            0.0                         32.999
# 2                            0.0                         25.999
# 3                            0.0                         27.999
# 4                            0.0                         29.999
#
#    SDH.SW.MSB.MS41A.PWR REAL 3 P  SDH.SW.MSB.MAIN.PWR REAL 3 P        value  \
# 0                            0.0                       379.999  1044.000000
# 1                            0.0                       367.999  1007.666667
# 2                            0.0                       363.499  1000.333333
# 3                            0.0                       368.999   998.000000
# 4                            0.0                       366.499   998.333333
#
#          moer
# 0  473.976000
# 1  457.480667
# 2  454.151333
# 3  453.092000
# 4  453.243333

# %%
df_emissions = df_temp.copy()

# Multiply all columns except the first and last by the last column
df_emissions.iloc[:, 1:-1] = df_emissions.iloc[:, 1:-1].multiply(df_emissions.iloc[:, -1], axis="index") / 1000
df_emissions = df_emissions.drop(columns=['value', 'moer'])
# Now 'new_df' is the new DataFrame with the desired calculations

df_emissions.head()
# Out:
#                    datetime  SDH.SW.MSA.CD4RA.PWR REAL 3 P  \
# 0 2023-01-20 15:45:00-08:00                      11.848926
# 1 2023-01-20 16:00:00-08:00                      12.351521
# 2 2023-01-20 16:15:00-08:00                      11.353329
# 3 2023-01-20 16:30:00-08:00                      10.873755
# 4 2023-01-20 16:45:00-08:00                      10.877387
#
#    SDH.SW.MSA.ATS-ES.PWR REAL 3 P  SDH.SW.MSA.MSB.TIE.PWR REAL 3P  \
# 0                        8.057118                             0.0
# 1                        8.234195                             0.0
# 2                        7.947194                             0.0
# 3                        7.702111                             0.0
# 4                        8.157927                             0.0
#
#    SDH.SW.MSA.MS41A.PWR REAL 3 P  SDH.SW.MSA.MDC.PWR REAL 3 P  \
# 0                     157.359558                    10.900974
# 1                     151.425643                    10.979079
# 2                     151.913167                    11.126254
# 3                     144.988987                    10.873755
# 4                     147.756873                    10.650765
#
#    SDH.SW.MSA.ATS-E2.PWR REAL 3 P  SDH.SW.MSB.MS41B.PWR REAL 3 P  \
# 0                       14.692782                      85.315206
# 1                       14.181443                      81.431101
# 2                       12.715783                      79.703105
# 3                       11.326847                      84.727751
# 4                       14.050090                      72.971723
#
#    SDH.SW.MSA.MAIN.PWR REAL 3 P  SDH.SW.MSA.MSB.PWR REAL 3 P  \
# 0                    254.998614                          0.0
# 1                    247.039103                          0.0
# 2                    248.420325                          0.0
# 3                    242.856859                          0.0
# 4                    245.884055                          0.0
#
#    SDH.SW.MSB.ATS-EL.PWR REAL 3 P  SDH.SW.MSA.ATS-E1.PWR REAL 3 P  \
# 0                       44.553270                       28.438086
# 1                       43.917687                       26.990902
# 2                       46.777133                       31.790139
# 3                       43.043287                       27.185067
# 4                       45.323880                       27.647390
#
#    SDH.SW.MSB.CB4A.PWR REAL 3 P  SDH.SW.MSA.CH-2.PWR REAL 3 P  \
# 0                     26.542182                     34.125798
# 1                     25.618460                     33.853112
# 2                     26.340323                     32.244291
# 3                     25.372699                     33.528355
# 4                     24.927930                     31.273337
#
#    SDH.SW.MSA.MS41B.PWR REAL 3 P  SDH.SW.MSA.CD41A.PWR REAL 3 P  \
# 0                            0.0                      14.218806
# 1                            0.0                      15.096405
# 2                            0.0                      11.807481
# 3                            0.0                      12.686123
# 4                            0.0                      13.596847
#
#    SDH.SW.MSB.MS41A.PWR REAL 3 P  SDH.SW.MSB.MAIN.PWR REAL 3 P
# 0                            0.0                    180.110406
# 1                            0.0                    168.352428
# 2                            0.0                    165.083556
# 3                            0.0                    167.190495
# 4                            0.0                    166.113228

# %%
import matplotlib.pyplot as plt

date = '2023-11-14'
df = df_emissions[df_emissions['datetime'].dt.date == pd.to_datetime(date)]

plt.figure(figsize=[20, 10])

for i in columns:
    plt.plot(df['datetime'], df[i], label = i)

plt.xlabel('Datetime', fontsize = 15)
plt.ylabel('Marginal carbon emissions (kg)', fontsize = 15)
plt.title('Calculation of marginal carbon emissions of MSA', fontsize = 18)
plt.legend()
# Out:
# /Users/aoyuzou/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)

# %%
process.plot_hourly_heatmap(df_emissions, columns)

# %%
import seaborn as sns

def create_violin_plot(df, columns):
    # Create the violin plot
    plt.figure(figsize=[20, 10])
    ax = sns.violinplot(data=df[columns])
    
    # Calculate and print mean and median on the plot
    for i, col in enumerate(columns):
        # Calculate statistics
        mean = df[col].mean()
        median = df[col].median()
        
        # Annotate the statistics on the plot
        # plt.text(i + 0.1, mean, f'Mean: {mean:.2f}', horizontalalignment='center', size='small', color='black', weight='semibold')
        plt.text(i - 0.1, median, f'Median: {median:.2f}', horizontalalignment='center', size='small', color='black', weight='semibold')
    
    # Set the x and y labels
    ax.set_xlabel('Column')
    ax.set_ylabel('Values')
    
    # Show the plot
    plt.show()

# %%
create_violin_plot(df_emissions, ['SDH.SW.MSA.CH-2.PWR REAL 3 P', 'SDH.SW.MSA.MAIN.PWR REAL 3 P'])
